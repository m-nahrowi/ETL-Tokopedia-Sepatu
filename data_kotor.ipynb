# %%
import pandas as pd

# %%
df = pd.read_csv('tokopedia_sepatu2.csv')

# %%
df = df.rename(columns={'labelGroups':'sold'})

# %%
for i in df['sold']:
    print(i)
# Out:
# Diskon 5rb
# Cashback 7,9rb
# Cashback 2,7rb
# Cashback 4,3rb
# Cashback 11,1rb
# Diskon 10rb
# Cashback 5,5rb
# Cashback 4,1rb
# Cashback 1,3rb
# Cashback 3,9rb
# Cashback 14,9rb
# Cashback 2,3rb
# Diskon 5rb
# 2rb+ terjual
# Cashback 4,3rb
# 3rb+ terjual
# Cashback 32,8rb
# Cashback 2,3rb
# Cashback 4,8rb
# Cashback 2,4rb
# Cashback 8rb
# Cashback 2,7rb
# Cashback 2,1rb
# Terlaris
# Diskon 5rb
# Sisa 8
# Sisa 7
# Cashback 25,1rb
# Cashback 7,1rb
# Cashback 4,3rb
# Diskon 5rb
# Cashback 4,9rb
# Diskon 5rb
# Cashback 2,5rb
# Cashback 4,3rb
# Cashback 37,6rb
# 40+ terjual
# Cashback 43,1rb
# Cashback 8rb
# Cashback 5,1rb
# Sisa 2
# Cashback 1,5rb
# Diskon 17,9rb
# Cashback 1,3rb
# Cashback 1,9rb
# Cashback 14,2rb
# Cashback 6,5rb
# Cashback 14,9rb
# Cashback 1rb
# Diskon 17,9rb
# 1rb+ terjual
# Cashback 3,7rb
# Cashback 1,4rb
# Cashback 6,9rb
# Cashback 2,2rb
# Cashback 4,8rb
# Cashback 5rb
# Cashback 2,4rb
# Terlaris
# Cashback 2,3rb
# Cashback 2,6rb
# 750+ terjual
# Cashback 2,3rb
# ...
